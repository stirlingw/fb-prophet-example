# %%
# Python
import pandas as pd
import numpy as np
from fbprophet import Prophet
# %matplotlib inline

// https://facebookincubator.github.io/prophet/docs/quick_start.html

# %%
# Python
df = pd.read_csv('./data/example_wp_peyton_manning.csv')
df['y'] = np.log(df['y'])
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
# Python
m = Prophet()
m.fit(df);

# %%
# Python
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
# Python
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.213787    7.485976    8.931031
# 3266 2017-01-16  8.538876    7.828861    9.274287
# 3267 2017-01-17  8.326293    7.667426    9.066440
# 3268 2017-01-18  8.158930    7.418243    8.846225
# 3269 2017-01-19  8.170898    7.401572    8.898545

# %%
# Python
m.plot(forecast);

# %%
# Python
m.plot_components(forecast);
